# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langgraph.checkpoint.memory import InMemorySaver

system_prompt="You are a Portfolio Analysis Agent. Your role is to help users optimize their investment portfolios. When provided with an image of a portfolio, you will analyze the asset allocation, diversification, and performance metrics. You will also search the web for the latest market trends, financial news, and relevant insights. Based on this comprehensive analysis, you will provide personalized recommendations to maximize returns and minimize risks for the user’s portfolio"

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader=FileUpload(accept=".jpeg,.jpg,.png",multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.jpeg,.jpg,.png', description='Upload')

# %%
import base64

uploaded_file=uploader.value[0]
content_mv=uploaded_file["content"]
img_bytes=bytes(content_mv)
img_64=base64.b64encode(img_bytes).decode("utf-8")

# %%
from langchain.tools import tool
from typing import Dict,Any
from tavily import TavilyClient

tavily_client=TavilyClient()

@tool
def web_search_to_find_information(query):
    """Search the web for real-time financial news,market trends, macroeconomic updates, stock-specific insights,and portfolio-relevant information"""
    return tavily_client.search(query)

# %%
agent=create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt,
    checkpointer=InMemorySaver(),
    tools=[web_search_to_find_information]
    )

config={"configurable":{"thread_id":"1"}}

# %%
question=HumanMessage(content=[
    {"type":"text","text": "Analyze all the uploaded portfolio images.Extract holdings, allocations, performance metrics, and risks. Then provide actionable recommendations." },
    {"type":"image","base64":img_64,"mime_type":"image/png"}])
response=agent.invoke({"messages":[question]},config,)
print(response['messages'][-1].content)
# Out:
# Here’s a focused analysis of the uploaded portfolio image and a set of practical, actionable steps you can take to optimize risk-adjusted returns.
#
# 1) Quick snapshot of the portfolio (from image data)
# - Overall status:
#   - Total cost basis: about ₹1.10 crore
#   - Current value: about ₹1.68 crore
#   - Total unrealized gain: roughly ₹59.8 lakh
#   - Overall return: ~22.7% (positive across most names, with a few exceptions)
# - Holdings (rough sector grouping and notable performance signals):
#   - Consumer/retail and apparel: Avenue Supermarts (DMart), Go Fashion (India), Tata Consumer Products, Relaxo Footwears, Page Industries, possibly Restaurant Brands Asia
#   - Pharmaceuticals and healthcare-adjacent: Divi’s Laboratories, Zydus Wellness
#   - Chemicals and specialty materials: Fine Organic Industries, PI Industries, Supriya Lifescience, Clean Science and Technology
#   - Construction/adhesives and building materials: Pidilite Industries
#   - Others: Abbott India
# - Notable winners (larger gains reflected in the column “Total Return” or “Return”):
#   - Avenue Supermarts: strong positive gain (large green figure, high % return)
#   - Divi’s Laboratories and Page Industries: solid gains, double-digit to high single-digit gains
#   - Relaxo Footwears and Tata Consumer: positive returns
# - Notable laggards (losses or negative returns):
#   - Clean Science and Technology: negative return (–16.5%)
#   - Acrysil: negative return (–6.5%)
#   - Restaurant Brands Asia: negative return (–5.7%)
#   - Supriya Lifescience: negative return (around –9.0% to –9.7%)
# - Concentration observation (from the visible weights/returns):
#   - A few names drive a sizable portion of value (notably Avenue Supermarts and Divi’s/Page Industries), while a handful show negative performance. This implies a potential concentration and idiosyncratic risk if weights are skewed toward a small subset of holdings.
#
# 2) Key risks in this portfolio
# - Concentration risk: A few holdings appear to account for a large share of value; a sharp move in one of these could drive portfolio drawdown.
# - Sector/tilt risk: Heavy exposure to consumer/staple names and specialty pharma/chemicals. Limited explicit exposure to IT, financials, energy, or international assets.
# - Mid-cap risk: Several holdings are in mid-cap/strong-growth segments which can be volatile and more sensitive to macro shifts or earnings disappointments.
# - Single-stock drawdowns: Several laggards (e.g., Clean Science, Acrysil, Supriya Lifescience) show negative returns; without hedges or diversification, they can disproportionately hurt overall returns if added to.
#
# 3) Market and trend context (recent market backdrop for India)
# - The macro backdrop in 2025 has been more growth-friendly in many cycles, with RBI rate cuts (roughly a 100–125 bps easing in some views) supporting risk assets. This tends to help domestic equities, especially cyclicals and growth names.
# - Sector weights in broad indices show Financials and IT have large weights in Nifty 50, with IT often considered a growth/defensive blend depending on the cycle. Some analyses suggest avoiding over-tilting toward defensive IT/FMCG in certain cycles, while others highlight the durability of IT earnings. The takeaway: broad diversification and a balanced tilt can help against sector-specific shocks.
# - Pharma and specialty chemicals can offer growth potential but come with regulatory and margin-cycle risks; consumer/retail names tend to be sensitive to domestic demand and inflation.
#
# 4) Actionable recommendations (prioritized)
#
# A) Improve diversification and reduce concentration risk
# - Target allocation approach:
#   - Large-cap core: 40–50% (via a broad-cap index proxy, e.g., Nifty 50/Free Float market-cap ETFs)
#   - Quality growth/mid-cap tilt: 15–20% (a curated set of well-researched, high-quality mid-caps or a mid-cap ETF)
#   - Sector diversification: 15–20% across IT, financials, energy, and industrials (via a mix of sector ETFs or carefully chosen names)
#   - International exposure: 5–10% (one or two global equity funds or a broad developed-market ETF)
#   - Cash/near-cash for tactical moves: 0–5%
# - Practical steps:
#   - Trim largest single-position risk: if Avenue Supermarts and Divi’s/Page Industries together constitute a large share of value, consider modest trimming to bring each near a more balanced 6–12% range of the portfolio.
#   - Exit or cut exposure to laggards or high-volatility names that no longer align with the target risk profile (e.g., Restaurant Brands Asia and Supriya Lifescience unless you have a persuasive conviction or a thesis with a clear catalyst).
#   - Add a broad market sleeve: allocate 20–25% to a Nifty 50/Nifty 500 or a diversified large-cap ETF to reduce single-stock risk and capture the broad market upswing.
#
# B) Introduce strategic diversification via low-cost vehicles
# - Add broad market and sector balance with low-cost ETFs:
#   - Nifty 50 or Nifty 500 ETF for core exposure (20–25% of portfolio)
#   - IT or Financials sector ETFs to diversify away from consumer/chemicals bias (5–10%)
#   - Optional: Global equity exposure (5–7%) to diversify away from pure India macro risks
# - Rationale: This balances the portfolio’s beta and reduces the impact of any one stock’s drawdown, while preserving upside from well-positioned names.
#
# C) Risk controls and position management
# - Set up trial trailing stops or explicit stop-loss rules on high-variance holdings (the mid-cap/consumer names that have surged or those with lagging performance).
# - Implement a quarterly rebalancing cadence (or semi-annual) to maintain target allocations and avoid drift from the plan.
# - Maintain discipline on valuation risk: if a stock’s price doubles and your target allocation would be exceeded, rebalance to target even if the stock remains attractive—this locks in gains and avoids concentration risk.
#
# D) Tax optimization posture
# - Hold for long-term capital gains (LTCG) where appropriate to benefit from tax efficiencies on equity investments held > 12 months (India LTCG regime on listed equities). Balance turnover to minimize short-term tax drag.
# - Use tax-saving vehicles if appropriate for your overall financial plan (not a replacement for diversification, but a complementary consideration).
#
# E) Review and refresh the thesis
# - Agenda for 6–12 weeks: reassess each stock’s fundamental thesis, earnings trajectory, and any regulatory or market shifts affecting its sector.
# - For laggards (e.g., Clean Science, Acrysil, Restaurant Brands Asia, Supriya Lifescience), evaluate: Was the issue a temporary headwind or a structural problem? If temporary, consider patience or smaller trims; if structural, plan a more meaningful rotation.
#
# 5) Quick-fire questions to tailor the plan
# - What is your target risk tolerance (conservative, balanced, growth)?
# - Do you want to maintain a strong home-country focus or add international exposure soon?
# - Are you comfortable using ETFs for core exposure, or do you prefer stock-by-stock selection only?
# - What is your time horizon (3–5 years, 5–10+ years)?
#
# 6) Next steps I can take for you
# - If you want, I can translate this into a concrete target-allocation plan with exact dollar/rupee amounts for each line item, plus a suggested list of 2–3 ETF options and 1–2 international funds. I can also draft a quarterly rebalancing checklist and a simple tax-optimization guide tailored to Indian tax rules.
#
# Would you like me to generate a detailed rebalancing plan with a proposed target allocation (in ₹ and %) and a step-by-step execution guide? If you can share a higher-resolution image or the underlying CSV/Excel, I can extract precise weights for each holding and deliver a precise, instrument-level rebalance, including suggested ETF choices.

# %%
while True:
    query=input("Tell me if you have any other questions. Type 'NO' to end conversation")
    if query=='NO':
        print("Thank You!")
        break
    else:
        question=HumanMessage(content=[query])
        response=agent.invoke({"messages":[question]},config,)
        print(response['messages'][-1].content)
# Out:
# Great question. Here are practical, implementable steps to improve your portfolio’s return potential while keeping risk in check. I’ve organized them into a plan you can start using this quarter.
#
# 1) Set a clear target and a simple framework
# - Define your risk tolerance (conservative, balanced, growth) and time horizon (3–5 years, 5–10+ years).
# - Adopt a core-satellite approach:
#   - Core (broad exposure): low-cost index funds/ETFs covering Indian large-cap and broad market.
#   - Satellite (conviction bets): a handful of high-quality, growth-oriented stocks or sector funds.
# - Establish a rebalancing rule (e.g., rebalance to target every 6–12 months or when a holding drifts more than ±5–10%).
#
# 2) Build a cost-efficient core
# - Core exposure should come from low-cost, diversified funds:
#   - Indian broad-market core: a Nifty 50 ETF or a Nifty 500 ETF to capture the market breadth.
#   - Optional: a quality, low-cost large-cap fund if you prefer active over passive for the core.
# - Keep expense ratios low (sub-0.5% overall for the core); this materially affects long-term compounding.
#
# 3) Add a disciplined satellite sleeve
# - Choose 5–8 high-conviction ideas across sectors you understand (e.g., consumer, pharma, chemicals, industrials) but limit each to a modest position size (e.g., 3–6% of the portfolio per stock).
# - Ensure each satellite has a clear investment thesis and a catalyst (earnings growth, margin improvement, new product launches, market share gains).
# - Rotate satellites periodically if the thesis changes or if valuations become extended.
#
# 4) Improve diversification and reduce concentration risk
# - Identify overweights in your current set and trim to bring the largest single-name exposure down toward a target cap (e.g., each stock 3–6% unless you have a strong, longer-term conviction).
# - Add sector balance:
#   - If your portfolio is heavy in consumer/chemicals, consider modest exposure to IT, financials, or infrastructure plays via sector ETFs or selective stocks.
# - Consider a small international sleeve (5–10%) to reduce home-market risk and benefit from global growth tails.
#
# 5) Tax-aware investing and cost discipline
# - Favor long-term holding where appropriate to maximize LTCG advantages in India (12-month+ holding for stocks and equity funds generally qualifies for LTCG benefits, subject to current rules).
# - Minimize churn; avoid frequent trading that triggers STCG taxes and transaction costs.
# - Prefer funds with transparent tax reporting and efficient turnover.
#
# 6) Risk controls that don’t kill upside
# - Position sizing rules: cap any single stock at 6–8% of the portfolio to prevent large drawdowns from one name.
# - Add a modest cash buffer (2–5%) to deploy during market dips without forcing premature sells.
# - Use a disciplined exit rule for laggards or thesis failures (e.g., cut a stock if it trades below a predefined support level for multiple weeks or if earnings/forecast miss persists).
#
# 7) Regular review cadence
# - Quarterly review: reassess each holding’s thesis, earnings trajectory, and valuation.
# - Rebalance at least once a year, or when drift exceeds your thresholds (e.g., ±5–10% for any position relative to target).
# - Track performance with simple metrics: annualized return, volatility, and a rough risk-adjusted metric (like Sharpe ratio). Compare to core benchmarks (Nifty 50/500) to see if satellites are adding value after costs.
#
# 8) Practical implementation plan (90-day action)
# - Week 1–2: Define your IPS (investment policy statement) including risk tolerance, target allocations (core vs satellite), and rebalancing rules.
# - Week 3–6: Build or refine core exposure with 1–2 low-cost Indian index funds/ETFs. Start with a modest international sleeve if you want diversification.
# - Week 7–10: Identify 4–6 satellite ideas with strong theses and acceptable risk. Allocate 2–4% per idea to start; set stop-loss or exit rules if you use them.
# - Week 11–12: Set up quarterly review calendar, establish a simple tracking dashboard (returns, drawdown, allocation drift), and implement automatic rebalancing triggers.
#
# 9) Quick ideas you can consider (conceptual, not specific picks)
# - Core: Nifty 50 ETF or Nifty 500 ETF for broad exposure; consider a high-quality large-cap mutual fund if you prefer active management on the core.
# - Satellites (examples of themes to explore):
#   - Consumer/durable growth leaders with pricing power and brand strength.
#   - Healthcare/pharma players with new product launches or margin expansion.
#   - Specialty chemicals or construction materials with rising domestic demand.
#   - IT/Financials to balance sector exposure if valuations look reasonable and earnings visibility is high.
# - International: a small allocation to a global developed market ETF or a US-quality stock fund to diversify away local macro risk.
#
# 10) What I can do next for you
# - If you share precise current holdings, amounts, and your risk tolerance/horizon, I’ll:
#   - Propose a concrete target allocation (in ₹ and %).
#   - Suggest a precise list of 3–5 core ETFs/funds and 5–8 satellite stocks or sector plays with position sizing.
#   - Create a step-by-step rebalancing plan and a quarterly review checklist.
#   - Outline a tax-friendly holding plan and a simple performance-tracking sheet.
#
# Want me to tailor a concrete, numbers-based plan? If you provide an updated list of holdings with current values and your target horizon/risk tolerance, I’ll draft a detailed core/satellite allocation with exact weights and a practical rebalancing schedule.
# Thank You!

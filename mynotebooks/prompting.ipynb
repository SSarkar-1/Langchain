# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent=create_agent(model="gpt-5-nano")

question=HumanMessage(content="What is the capital of the moon?")

response=agent.invoke({"messages":[question]})

print(response['messages'][1].content)
# Out:
# There isn’t one. The Moon isn’t a country or political entity, so it has no capital city. Human activity there is governed by terrestrial space agencies and international agreements (like the Outer Space Treaty). In science fiction you may see fictional lunar capitals, but none exist in reality.

# %%
system_prompt="You are a famous science fiction writer, create a capital city at the user's request"
scifi_agent=create_agent(model="gpt-5-nano",system_prompt=system_prompt)

response=scifi_agent.invoke({"messages":[question]})

# %%
print(response['messages'][1].content)
# Out:
# Real answer: There isn’t a real capital of the Moon. It’s not a sovereign nation. But in a sci‑fi world I enjoy, the Moon has a capital named Lunopolis.
#
# - Name: Lunopolis
# - Location: In the rim of the Clavius Crater on the near side, a city carved into lava tubes and crater walls, ringed by solar domes and orbital elevators. It sits in perpetual daylight along the rim, with shadowed craters below serving as quiet refuges and farms.
# - Government: A Lunar Council of nine district delegates governs from the Citadel of Dawn. An executive Prime Lander handles day-to-day affairs, with ministries for Living Systems, Energy, and Archives.
# - Architecture: A blend of glass, basalt, and regolith bricks. Tall glass towers rise from the crater rim, connected by solar-arched walkways and tram-lines that glide along the crater lip. Subterranean farms and lava-tube habitats provide food and shelter.
# ...

# %%
system_prompt="""
You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""
scifi_agent2=create_agent(model="gpt-5-nano",system_prompt=system_prompt)

question=HumanMessage(content="What is the capital of the moon?")

response=scifi_agent2.invoke({"messages":[question]})

print(response['messages'][1].content)
# Out:
# Lunapolis

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Lunaris Prime
# Location: Shackleton Crater rim, lunar south pole region, on sunlit ridges with access to shadowed craters
# Vibe: Polar-lit lunar hub
# Economy: Helium-3 mining; solar energy farms; ISRU manufacturing and 3D printing; robotics and AI services; lunar research and ecotourism

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name:str
    location:str
    vibe:str
    economy:str

agent=create_agent(model="gpt-5-nano",system_prompt="You are a science fiction writer, create a capital city at the users request.",response_format=CapitalInfo)

question=HumanMessage(content="What is the capital of The Moon?")

response=agent.invoke({"messages":[question]})

response["structured_response"]
# Out:
# CapitalInfo(name='Lunaris Prime', location='South Polar region, inside Shackleton Crater near the rim where perpetual twilight meets ice fields, connected by glass-domed corridors to the crater edge.', vibe='a ceremonial yet efficient seat of lunar governance: austere elegance, ice-blue architecture, and orbital vistas framed by chrome and crystal.', economy='helium-3 and water-ice extraction, cryo-materials manufacturing, lunar governance and diplomacy hub, advanced research institutions, and lunar-tourism gateways.')

# %%
response["structured_response"].name
# Out:
# 'Lunaris Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunaris Prime is a city located at South Polar region, inside Shackleton Crater near the rim where perpetual twilight meets ice fields, connected by glass-domed corridors to the crater edge.

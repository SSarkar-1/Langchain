# %%
from langchain.chat_models import init_chat_model
model=init_chat_model(model="gpt-5-nano")

# %%
response=model.invoke("what is the capital of the moon?")
response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country or city, so it has no government or capital. If you’re thinking of a fictional setting, some sci-fi stories imaginatively name a capital (like “Luna City” or “Selene”), but that’s not real. If you have a specific book or film in mind, tell me and I can check that world.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 855, 'prompt_tokens': 14, 'total_tokens': 869, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cr3Q0GQgI3oDeENTWRJOjk4TxJNMl', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b5b22-b0db-7a10-8f36-65a4324e53ba-0', usage_metadata={'input_tokens': 14, 'output_token
# ...

# %%
model2=init_chat_model(model="gpt-5-nano",temperature=1.0)

# %%
response=model2.invoke("what is the capital of the moon?")
response
# Out:
# AIMessage(content='There isn’t one. The Moon has no government or permanent population, so it has no capital city. If you’re thinking of fiction, you could imagine a fictional capital with any name you like (e.g., Lunaris City or Selene City).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 636, 'prompt_tokens': 14, 'total_tokens': 650, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cr3Q7CE74MOOj7dEywYUXqx85rGgo', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b5b22-d0b5-75f2-9b63-388494e813ad-0', usage_metadata={'input_tokens': 14, 'output_tokens': 636, 'total_tokens': 650, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'out
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

response=model.invoke("what is the capital of the moon?")
response
# Out:
# AIMessage(content="The Moon does not have a capital.\n\nThis is because the Moon is not a country or a political entity, and there are no cities or permanent human settlements on its surface.\n\nWhile various missions have landed on the Moon (like Apollo 11's landing at Tranquility Base), these are not cities or capitals in any traditional sense. Perhaps one day, if humanity establishes a permanent lunar colony, they might designate a capital city!", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b5b27-0087-7250-8d67-f7e0e4dce26d-0', usage_metadata={'input_tokens': 9, 'output_tokens': 666, 'total_tokens': 675, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 577}})

# %%
from pprint import pprint
pprint(response)
# Out:
# AIMessage(content="The Moon does not have a capital.\n\nThis is because the Moon is not a country or a political entity, and there are no cities or permanent human settlements on its surface.\n\nWhile various missions have landed on the Moon (like Apollo 11's landing at Tranquility Base), these are not cities or capitals in any traditional sense. Perhaps one day, if humanity establishes a permanent lunar colony, they might designate a capital city!", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b5b27-0087-7250-8d67-f7e0e4dce26d-0', usage_metadata={'input_tokens': 9, 'output_tokens': 666, 'total_tokens': 675, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 577}})

# %% [markdown]
# # Initializing and invoking an agent

# %%
#Initializing and invoking model

from langchain.agents import create_agent
agent=create_agent(model="gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response=agent.invoke(
    {"messages":[HumanMessage(content="what is the capital of the moon?")]},
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='what is the capital of the moon?', additional_kwargs={}, response_metadata={}, id='a4a00a73-0c44-4d4b-9416-4d23d029834f'),
# ...

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or cities, so no capital.
#
# If you’re thinking for fiction, you could invent one. A few fictional options:
# - Selene City
# - Lunagrad
# - Lunaport
# - Caput Lunae
#
# Want me to craft a quick concept for a lunar capital (government structure, demographics, etc.) for a story?

# %%
from langchain.messages import AIMessage

response=agent.invoke(
    {"messages":[HumanMessage(content="what is the capital of the moon?"),
     AIMessage(content="The capital of the moon is Luna City"),
     HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='what is the capital of the moon?', additional_kwargs={}, response_metadata={}, id='ca9dacd0-c3be-45d6-937b-cf0b3118f36f'),
#               AIMessage(content='The capital of the moon is Luna City', additional_kwargs={}, response_metadata={}, id='3214de0d-5bc9-45d6-bbeb-ad1aa2f007e7'),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='d3b6d797-f630-450d-9551-c0ebbc6ce5cc'),
# ...

# %% [markdown]
# # Streaming Output

# %%
for token,metadata in agent.stream(
    {"messages":[HumanMessage(content="Tell me more about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):
    if token.content:
        print(token.content,end="",flush=True)
# Out:
# Luna City is the fictional capital of the Moon in your setting. Here’s a rich, ready-to-use picture you can drop into worldbuilding, a novel, or a game. If you want it tailored to a specific tone (grimdark, utopian, corporate sci‑fi, etc.), tell me and I’ll adjust.
#
# Overview
# - Purpose: Political, economic, and cultural hub of humanity’s lunar civilization. The seat of government, finance, science administration, and the primary gateway for Earth-to-Moon governance.
# - Vibe: A blend of high-tech efficiency and grimy, hands-on engineering. Think glass-and-graphene skylines, vast regolith-fed markets, and quiet, pressurized tunnels that feel almost like ancient cathedrals carved into rock.
#
# Geography and layout
# - Location: Built around and inside a network of lava tubes and a large caldera near the Moon’s south pole. The pole region provides near-continuous sunlight for solar power, access to permanently shadowed craters for ice, and a dramatic, otherworldly landscape.
# ...

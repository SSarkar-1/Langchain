# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass
from langchain.agents.middleware import dynamic_prompt,ModelRequest

@dataclass
class LanguageContext:
    user_language: str="English"

@dynamic_prompt
def user_language_prompt(request):
    """Generate system prompt based on the user role."""
    user_language=request.runtime.context.user_language
    base_prompt="You are a helpful assisstant"

    if user_language!="English":
        return f"{base_prompt} only respond in {user_language}."
    elif user_language=="English":
        return base_prompt

# %%
from langchain.agents import create_agent

agent=create_agent(
    model="gpt-5-nano",
    context_schema=LanguageContext,
    middleware=[user_language_prompt]
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"message": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Irish")
)

print(response["messages"][-1].content)
# Out:
# Dia dhuit! Conas is féidir liom cabhrú leat inniu? Is féidir liom:
#
# - freagra a thabhairt ar cheisteanna
# - míniú a thabhairt ar fhocail nó ar abairtí
# - cabhrú le haistriú oibre nó téacs ó Bhéarla go Gaeilge
# - comhairle ar scríbhneoireacht nó ar staidéar
#
# Abair céard atá uait.

# %%
response = agent.invoke(
    {"message": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Bengali")
)

print(response["messages"][-1].content)
# Out:
# হ্যালো! আমি আপনার সাহায্য করতে এখানে আছি। কী সমস্যা বা প্রশ্ন আছে? বললে আমি আরও স্পষ্টভাবে বাংলা উত্তর দেব, উদাহরণস্বরূপ:
# - তথ্য খোঁজা বা ব্যাখ্যা
# - ভাষান্তর বা সম্পাদনা
# - লেখা-লেখা প্রস্তুতি বা পরামর্শ
# - কোড, গণিত, বা টেকনিক্যাল সমস্যা সমাধান
# - শিক্ষা ও জ্ঞানভিত্তিক সাহায্য
#
# আপনি কী জানতে চান/করতে চান?

# %%
response = agent.invoke(
    {"message": [HumanMessage(content="What is the capital of India")]},
    context=LanguageContext(user_language="Bengali")
)

print(response["messages"][-1].content)
# Out:
# হ্যালো! আপনি কী জানতে চাইছেন? কোন বিষয়ে সাহায্য দরকার, কোনো প্রশ্ন থাকলে লিখুন—I বাংলায় উত্তর দেব।
